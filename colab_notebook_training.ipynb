# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !apt-get update

# %%
# %cd /content/drive/MyDrive/maskdetection_model

# %%
# !unzip darknet.zip

# %%
# %mv darknet /content

# %%
# !chmod +x /content/darknet

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# !make

# %%
# !rm /content/darknet/backup -r

# %%
# !ln -s /content/drive/MyDrive/maskdetection_weights/backup/ /content/darknet

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# !./darknet detector train maskdetection_data/maskdetection.data mask_detection_yolov4.cfg backup/mask_detection_yolov4_last.weights –map -dont_show
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#  total_bbox = 295907, rewritten_bbox = 0.024332 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.942773), count: 1, class_loss = 0.000005, iou_loss = 0.253520, total_loss = 0.253525
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.930570), count: 2, class_loss = 0.000002, iou_loss = 0.447828, total_loss = 0.447830
#  total_bbox = 295910, rewritten_bbox = 0.024332 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...
